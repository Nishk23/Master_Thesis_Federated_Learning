# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade flwr
# Out:
# Collecting flwr
#   Downloading flwr-1.18.0-py3-none-any.whl.metadata (15 kB)
# Collecting cryptography<45.0.0,>=44.0.1 (from flwr)
#   Downloading cryptography-44.0.3-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: grpcio!=1.65.0,<2.0.0,>=1.62.3 in /usr/local/lib/python3.11/dist-packages (from flwr) (1.71.0)
# Collecting iterators<0.0.3,>=0.0.2 (from flwr)
#   Downloading iterators-0.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from flwr) (2.0.2)
# Collecting pathspec<0.13.0,>=0.12.1 (from flwr)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting protobuf<5.0.0,>=4.21.6 (from flwr)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pycryptodome<4.0.0,>=3.18.0 (from flwr)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.11/dist-packages (from flwr) (6.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from flwr) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.5.0 in /usr/local/lib/python3.11/dist-packages (from flwr) (13.9.4)
# Collecting tomli<3.0.0,>=2.0.1 (from flwr)
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting tomli-w<2.0.0,>=1.0.0 (from flwr)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting typer<0.13.0,>=0.12.5 (from flwr)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<45.0.0,>=44.0.1->flwr) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->flwr) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->flwr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->flwr) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->flwr) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0.0,>=13.5.0->flwr) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0.0,>=13.5.0->flwr) (2.19.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<0.13.0,>=0.12.5->flwr) (8.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from typer<0.13.0,>=0.12.5->flwr) (4.13.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<0.13.0,>=0.12.5->flwr) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<45.0.0,>=44.0.1->flwr) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.5.0->flwr) (0.1.2)
# Downloading flwr-1.18.0-py3-none-any.whl (540 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.0/540.0 kB 11.4 MB/s eta 0:00:00
# Downloading cryptography-44.0.3-cp39-abi3-manylinux_2_34_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 85.9 MB/s eta 0:00:00
# Downloading iterators-0.0.2-py3-none-any.whl (3.9 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 27.6 MB/s eta 0:00:00
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 88.5 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 23.2 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: tomli-w, tomli, pycryptodome, protobuf, pathspec, iterators, cryptography, typer, flwr
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.15.3
#     Uninstalling typer-0.15.3:
#       Successfully uninstalled typer-0.15.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 44.0.3 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 44.0.3 which is incompatible.
# Successfully installed cryptography-44.0.3 flwr-1.18.0 iterators-0.0.2 pathspec-0.12.1 protobuf-4.25.8 pycryptodome-3.23.0 tomli-2.2.1 tomli-w-1.2.0 typer-0.12.5

# %%
# !pip install -U "flwr[simulation]"
# Out:
# Requirement already satisfied: flwr[simulation] in /usr/local/lib/python3.11/dist-packages (1.18.0)
# Requirement already satisfied: cryptography<45.0.0,>=44.0.1 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (44.0.3)
# Requirement already satisfied: grpcio!=1.65.0,<2.0.0,>=1.62.3 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (1.71.0)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (0.0.2)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (2.0.2)
# Requirement already satisfied: pathspec<0.13.0,>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (0.12.1)
# Requirement already satisfied: protobuf<5.0.0,>=4.21.6 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (4.25.8)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (3.23.0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (6.0.2)
# Collecting ray==2.31.0 (from flwr[simulation])
#   Downloading ray-2.31.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.5.0 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (13.9.4)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (2.2.1)
# Requirement already satisfied: tomli-w<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (1.2.0)
# Requirement already satisfied: typer<0.13.0,>=0.12.5 in /usr/local/lib/python3.11/dist-packages (from flwr[simulation]) (0.12.5)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray==2.31.0->flwr[simulation]) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray==2.31.0->flwr[simulation]) (3.18.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray==2.31.0->flwr[simulation]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray==2.31.0->flwr[simulation]) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ray==2.31.0->flwr[simulation]) (24.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray==2.31.0->flwr[simulation]) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray==2.31.0->flwr[simulation]) (1.6.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<45.0.0,>=44.0.1->flwr[simulation]) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->flwr[simulation]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->flwr[simulation]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->flwr[simulation]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->flwr[simulation]) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0.0,>=13.5.0->flwr[simulation]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0.0,>=13.5.0->flwr[simulation]) (2.19.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from typer<0.13.0,>=0.12.5->flwr[simulation]) (4.13.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<0.13.0,>=0.12.5->flwr[simulation]) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<45.0.0,>=44.0.1->flwr[simulation]) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.5.0->flwr[simulation]) (0.1.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.31.0->flwr[simulation]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.31.0->flwr[simulation]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.31.0->flwr[simulation]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.31.0->flwr[simulation]) (0.25.1)
# Downloading ray-2.31.0-cp311-cp311-manylinux2014_x86_64.whl (66.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 MB 34.7 MB/s eta 0:00:00
# Installing collected packages: ray
# Successfully installed ray-2.31.0

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/
# !ls *.py
# Out:
# /content/drive/MyDrive/Colab Notebooks
# client.py  cnn_models.py  dataset.py  main.py  model.py  server.py

# %%
import torch
print("GPU available:", torch.cuda.is_available())
print("Device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")
# Out:
# GPU available: True
# Device name: NVIDIA A100-SXM4-40GB

# %% [markdown]
# # model.py

# %%
# %%writefile "/content/drive/MyDrive/Colab Notebooks/model.py"
#
# import torch
# import torch.nn as nn
# import torchvision.models as models
#
# # Helper to auto-detect flattened size
# class FlattenedSizeDetector(nn.Module):
#     def __init__(self, feature_extractor):
#         super().__init__()
#         self.features = feature_extractor
#
#     def forward(self, x):
#         with torch.no_grad():
#             x = self.features(x)
#             return x.view(x.size(0), -1).size(1)
#
# # ------------------------------
# # 1. TinyCNN (Input: 128x128)
# # ------------------------------
# class TinyCNN(nn.Module):
#     def __init__(self, num_classes=3):
#         super(TinyCNN, self).__init__()
#         self.features = nn.Sequential(
#             nn.Conv2d(3, 8, 3, padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(2),  # [8, 64, 64]
#         )
#         # Auto-detect flattened size
#         dummy_input = torch.zeros(1, 3, 128, 128)
#         flat_size = self.features(dummy_input).view(1, -1).size(1)
#
#         self.classifier = nn.Sequential(
#             nn.Flatten(),
#             nn.Linear(flat_size, num_classes)
#         )
#
#     def forward(self, x):
#         x = self.features(x)
#         return self.classifier(x)
#
# # ------------------------------
# # 2. SimpleCNN_V2 (Input: 128x128)
# # ------------------------------
# class SimpleCNN_V2(nn.Module):
#     def __init__(self, num_classes=3):
#         super(SimpleCNN_V2, self).__init__()
#         self.features = nn.Sequential(
#             nn.Conv2d(3, 32, kernel_size=3, padding=1),
#             nn.BatchNorm2d(32), nn.ReLU(), nn.MaxPool2d(2),  # -> [32, 64, 64]
#             nn.Conv2d(32, 64, kernel_size=3, padding=1),
#             nn.BatchNorm2d(64), nn.ReLU(), nn.MaxPool2d(2),  # -> [64, 32, 32]
#             nn.Conv2d(64, 128, kernel_size=3, padding=1),
#             nn.BatchNorm2d(128), nn.ReLU(),
#             nn.AdaptiveAvgPool2d((1, 1))  # -> [128, 1, 1]
#         )
#
#         dummy_input = torch.zeros(1, 3, 128, 128)
#         flat_size = self.features(dummy_input).view(1, -1).size(1)
#
#         self.classifier = nn.Sequential(
#             nn.Flatten(),
#             nn.Dropout(0.4),
#             nn.Linear(flat_size, 128), nn.ReLU(),
#             nn.Linear(128, 64), nn.ReLU(),
#             nn.Linear(64, num_classes)
#         )
#
#     def forward(self, x):
#         x = self.features(x)
#         return self.classifier(x)
#
# # ------------------------------
# # 3. ResNet-18
# # ------------------------------
# class ResNet18(nn.Module):
#     def __init__(self, num_classes=3):
#         super(ResNet18, self).__init__()
#         self.model = models.resnet18(pretrained=False)
#         self.model.fc = nn.Linear(self.model.fc.in_features, num_classes)
#
#     def forward(self, x):
#         return self.model(x)
#
# # ------------------------------
# # 4. MobileNetV2
# # ------------------------------
# class MobileNetV2(nn.Module):
#     def __init__(self, num_classes=3):
#         super(MobileNetV2, self).__init__()
#         self.model = models.mobilenet_v2(pretrained=False)
#         self.model.classifier[1] = nn.Linear(self.model.last_channel, num_classes)
#
#     def forward(self, x):
#         return self.model(x)
# Out:
# Overwriting /content/drive/MyDrive/Colab Notebooks/model.py

# %% [markdown]
# # dataset.py

# %%
# %%writefile "/content/drive/MyDrive/Colab Notebooks/dataset.py"
#
# import os
# import shutil
# import torch
# from torch.utils.data import DataLoader, random_split
# from torchvision import datasets, transforms
#
# def get_dataloaders(data_dir, batch_size=32, val_split=0.2, seed=42):
#
#     for class_dir in os.listdir(data_dir):
#         full_path = os.path.join(data_dir, class_dir)
#         if os.path.isdir(full_path) and len(os.listdir(full_path)) == 0:
#             print(f" Removing empty folder: {full_path}")
#             os.rmdir(full_path)
#
#     transform = transforms.Compose([
#         transforms.Resize((128, 128)),
#         transforms.ToTensor()
#     ])
#
#     full_dataset = datasets.ImageFolder(root=data_dir, transform=transform)
#
#     val_size = int(val_split * len(full_dataset))
#     train_size = len(full_dataset) - val_size
#
#     torch.manual_seed(seed)
#     train_ds, val_ds = random_split(full_dataset, [train_size, val_size])
#
#     train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
#     val_loader = DataLoader(val_ds, batch_size=batch_size)
#
#     return train_loader, val_loader
# Out:
# Overwriting /content/drive/MyDrive/Colab Notebooks/dataset.py

# %% [markdown]
# # server.py

# %%
# %%writefile "/content/drive/MyDrive/Colab Notebooks/server.py"
#
# import flwr as fl
#
# def get_strategy():
#     strategy = fl.server.strategy.FedAvg(
#         fraction_fit=1.0,
#         fraction_evaluate=1.0,
#         min_fit_clients=3,
#         min_evaluate_clients=3,
#         min_available_clients=3,
#     )
#     return strategy
# Out:
# Overwriting /content/drive/MyDrive/Colab Notebooks/server.py

# %% [markdown]
# # client.py

# %%
# %%writefile "/content/drive/MyDrive/Colab Notebooks/client.py"
#
# import flwr as fl
# from flwr.common import parameters_to_ndarrays, ndarrays_to_parameters
# from flwr.client import NumPyClient
# import torch
# import torch.nn.functional as F
# import torch.optim as optim
# import os
# import sys
# import csv
#
# sys.path.append('/content/drive/MyDrive/Colab Notebooks')
# from dataset import get_dataloaders
# from model import TinyCNN, SimpleCNN_V2, ResNet18, MobileNetV2
#
# LOG_DIR = "/content/drive/MyDrive/Colab Notebooks/logs"
# USE_GPU = os.environ.get("USE_GPU", "false").lower() == "true"
# DEVICE = torch.device("cuda" if USE_GPU and torch.cuda.is_available() else "cpu")
#
# def get_model(model_name, num_classes=3):
#     if model_name == "tinycnn":
#         return TinyCNN(num_classes).to(DEVICE)
#     elif model_name == "simplecnn":
#         return SimpleCNN_V2(num_classes).to(DEVICE)
#     elif model_name == "resnet18":
#         return ResNet18(num_classes).to(DEVICE)
#     elif model_name == "mobilenetv2":
#         return MobileNetV2(num_classes).to(DEVICE)
#     else:
#         raise ValueError(f"Unknown model name: {model_name}")
#
# class FlowerClient(NumPyClient):
#     def __init__(self, model_name, data_path, client_id, split_name="default"):
#         self.model = get_model(model_name)
#         self.train_loader, self.val_loader = get_dataloaders(data_path)
#         self.client_id = client_id
#         self.split_name = split_name
#
#         # Initialize log file
#         os.makedirs(LOG_DIR, exist_ok=True)
#
#         # Initialize log file
#         self.log_file = f"{LOG_DIR}/client_{client_id}_metrics_{model_name}_{split_name}.csv"
#         if not os.path.exists(self.log_file):
#             with open(self.log_file, "w", newline="") as f:
#                 writer = csv.writer(f)
#                 writer.writerow(["round", "loss", "accuracy"])
#
#     def get_parameters(self, config):
#         return [val.cpu().numpy() for _, val in self.model.state_dict().items()]
#
#     def set_parameters(self, parameters, config=None):
#         # Convert if needed
#         if hasattr(parameters, "tensors"):  # it's a Parameters object
#             parameters = parameters_to_ndarrays(parameters)
#
#         # Load into state_dict
#         state_dict = self.model.state_dict()
#         for k, val in zip(state_dict.keys(), parameters):
#             state_dict[k] = torch.tensor(val)
#         self.model.load_state_dict(state_dict, strict=True)
#
#     def fit(self, parameters, config):
#         self.set_parameters(parameters, config)
#         self.model.train()
#         optimizer = optim.Adam(self.model.parameters(), lr=0.001)
#
#         for epoch in range(1):
#             for x, y in self.train_loader:
#                 x, y = x.to(DEVICE), y.to(DEVICE)
#                 optimizer.zero_grad()
#                 y_hat = self.model(x)
#                 loss = F.cross_entropy(y_hat, y)
#                 loss.backward()
#                 optimizer.step()
#
#         return self.get_parameters(config), len(self.train_loader.dataset), {}
#
#     def evaluate(self, parameters, config):
#         self.set_parameters(parameters, config)
#         self.model.eval()
#
#         correct = 0
#         loss = 0.0
#         total = 0
#
#         with torch.no_grad():
#             for x, y in self.val_loader:
#                 x, y = x.to(DEVICE), y.to(DEVICE)
#                 y_hat = self.model(x)
#                 loss += F.cross_entropy(y_hat, y, reduction='sum').item()
#                 correct += (y_hat.argmax(1) == y).sum().item()
#                 total += y.size(0)
#
#         avg_loss = loss / total
#         accuracy = correct / total
#         round_number = config.get("server_round", 0)
#
#         # Log results to CSV
#         if config.get("server_side", False):
#             with open(self.log_file, "a", newline="") as f:
#                 writer = csv.writer(f)
#                 writer.writerow([round_number, avg_loss, accuracy])
#
#         return avg_loss, total, {"accuracy": accuracy}
# Out:
# Overwriting /content/drive/MyDrive/Colab Notebooks/client.py

# %% [markdown]
# # main.py

# %%
# %%writefile "/content/drive/MyDrive/Colab Notebooks/main.py"
#
# import sys
# sys.path.append('/content/drive/MyDrive/Colab Notebooks')
#
# import os
# import csv
# import flwr as fl
# from flwr.common import Context
# from flwr.simulation import start_simulation
# from client import FlowerClient
#
# # Constants
# LOG_DIR = "/content/drive/MyDrive/Colab Notebooks/logs"
# DATA_BASE = "/content/drive/MyDrive/Colab Notebooks/Covid19-dataset/splits"
# CLIENTS = []
#
# os.makedirs(LOG_DIR, exist_ok=True)
#
# # ------------------------------
# # Evaluation Function
# # ------------------------------
# def get_eval_fn(model_name, split_name):
#     def evaluate(server_round, parameters, config):
#         total_correct = 0
#         total_samples = 0
#         round_logs = []
#
#         for i, client in enumerate(CLIENTS):
#             # print(f"Client {i} evaluate arg count:", client.evaluate.__code__.co_argcount)
#             loss, num_samples, metrics = client.evaluate(parameters, config)
#             acc = metrics.get("accuracy", 0.0)
#             total_correct += acc * num_samples
#             total_samples += num_samples
#             round_logs.append([server_round, i, acc, loss])
#
#         # Log client metrics
#         log_client_path = f"{LOG_DIR}/log_client_metrics_{model_name}_{split_name}.csv"
#         with open(log_client_path, "a", newline="") as f:
#             writer = csv.writer(f)
#             if os.stat(log_client_path).st_size == 0:
#                 writer.writerow(["round", "client_id", "accuracy", "loss"])
#             writer.writerows(round_logs)
#
#         # Log global metrics
#         global_acc = total_correct / total_samples if total_samples > 0 else 0.0
#         log_global_path = f"{LOG_DIR}/log_global_metrics_{model_name}_{split_name}.csv"
#         with open(log_global_path, "a", newline="") as f:
#             writer = csv.writer(f)
#             if os.stat(log_global_path).st_size == 0:
#                 writer.writerow(["round", "global_accuracy"])
#             writer.writerow([server_round, global_acc])
#
#         return 0.0, {"accuracy": global_acc}
#
#     return evaluate
#
# # ------------------------------
# # Custom Strategy Subclass
# # ------------------------------
# class CustomFedAvg(fl.server.strategy.FedAvg):
#     def __init__(self, eval_fn, **kwargs):
#         super().__init__(**kwargs)
#         self._eval_fn_custom = eval_fn
#
#     def evaluate(self, server_round, parameters, config=None):  # Make config optional
#         if config is None:
#             config = {}  # Provide empty config if missing
#         config["server_round"] = server_round
#         config["server_side"] = True
#         return self._eval_fn_custom(server_round, parameters, config)
#
# # ------------------------------
# # Client Setup
# # ------------------------------
# def get_clients(model_name, split_name):
#     global CLIENTS
#     clients = []
#     for i in range(3):
#         data_path = os.path.join(DATA_BASE, split_name, f"Client-{i+1}")
#         # print(f"✅ Initialized client {i} with path: {data_path}")
#         client = FlowerClient(model_name, data_path, i, split_name)
#         clients.append(client)
#     CLIENTS = clients
#     return clients
#
# # ------------------------------
# # Run Simulation
# # ------------------------------
# def run_simulation(model_name, split_name):
#     clients = get_clients(model_name, split_name)
#     eval_fn = get_eval_fn(model_name, split_name)
#
#     strategy = CustomFedAvg(
#         eval_fn=eval_fn,
#         fraction_fit=1.0,
#         fraction_evaluate=1.0,
#         min_fit_clients=3,
#         min_evaluate_clients=3,
#         min_available_clients=3
#     )
#
#     def client_fn(cid: str):
#       return clients[int(cid)]
#
#     start_simulation(
#         client_fn=client_fn,
#         num_clients=3,
#         config=fl.server.ServerConfig(num_rounds=10),
#         strategy=strategy
#     )
#
# # ------------------------------
# # Entrypoint
# # ------------------------------
# if __name__ == "__main__":
#     if len(sys.argv) != 3:
#         print("Usage: python main.py <model_name> <split_name>")
#         sys.exit(1)
#
#     model = sys.argv[1].lower()
#     split = sys.argv[2]
#     run_simulation(model, split)
# Out:
# Overwriting /content/drive/MyDrive/Colab Notebooks/main.py

# %% [markdown]
# # Runner code

# %%
import subprocess
from tqdm import tqdm

models = ["tinycnn", "simplecnn", "resnet18", "mobilenetv2"]
splits = ["Label_skew", "Concept_shift", "Feature_skew", "Pathological", "Quantity_skew", "IID_equal", "Dirichlet_label"]

# Total runs = len(models) × len(splits)
total_runs = len(models) * len(splits)

with tqdm(total=total_runs, desc="Running experiments") as pbar:
    for split in splits:
        for model in models:
            tqdm.write(f"\n▶️  Running: {model} on {split}")
            subprocess.run(["python", "main.py", model, split])
            pbar.update(1)
# Out:
# Running experiments:   0%|          | 0/28 [00:00<?, ?it/s]
# ▶️  Running: tinycnn on Label_skew
# Running experiments:   4%|▎         | 1/28 [07:14<3:15:23, 434.19s/it]
# ▶️  Running: simplecnn on Label_skew
# Running experiments:   7%|▋         | 2/28 [16:38<3:41:16, 510.63s/it]
# ▶️  Running: resnet18 on Label_skew
# Running experiments:  11%|█         | 3/28 [27:33<4:00:12, 576.51s/it]
# ▶️  Running: mobilenetv2 on Label_skew
# Running experiments:  14%|█▍        | 4/28 [37:37<3:55:00, 587.53s/it]
# ▶️  Running: tinycnn on Concept_shift
# Running experiments:  18%|█▊        | 5/28 [50:05<4:07:18, 645.17s/it]
# ▶️  Running: simplecnn on Concept_shift
# Running experiments:  21%|██▏       | 6/28 [59:39<3:47:44, 621.13s/it]
# ▶️  Running: resnet18 on Concept_shift
# Running experiments:  25%|██▌       | 7/28 [1:10:34<3:41:16, 632.23s/it]
# ▶️  Running: mobilenetv2 on Concept_shift
# Running experiments:  29%|██▊       | 8/28 [1:20:29<3:26:45, 620.27s/it]
# ▶️  Running: tinycnn on Feature_skew
# Running experiments:  32%|███▏      | 9/28 [1:32:56<3:28:59, 659.95s/it]
# ▶️  Running: simplecnn on Feature_skew
# Running experiments:  36%|███▌      | 10/28 [1:42:30<3:10:03, 633.55s/it]
# ▶️  Running: resnet18 on Feature_skew
# Running experiments:  39%|███▉      | 11/28 [1:53:35<3:02:13, 643.13s/it]
# ▶️  Running: mobilenetv2 on Feature_skew
# Running experiments:  43%|████▎     | 12/28 [2:03:50<2:49:11, 634.46s/it]
# ▶️  Running: tinycnn on Pathological
# Running experiments:  46%|████▋     | 13/28 [2:04:01<1:51:25, 445.68s/it]
# ▶️  Running: simplecnn on Pathological
# Running experiments:  50%|█████     | 14/28 [2:04:10<1:13:14, 313.86s/it]
# ▶️  Running: resnet18 on Pathological
# Running experiments:  54%|█████▎    | 15/28 [2:04:20<48:06, 222.07s/it]
# ▶️  Running: mobilenetv2 on Pathological
# Running experiments:  57%|█████▋    | 16/28 [2:04:29<31:35, 157.98s/it]
# ▶️  Running: tinycnn on Quantity_skew
# Running experiments:  61%|██████    | 17/28 [2:19:16<1:09:09, 377.19s/it]
# ▶️  Running: simplecnn on Quantity_skew
# Running experiments:  64%|██████▍   | 18/28 [2:31:20<1:20:15, 481.55s/it]
# ▶️  Running: resnet18 on Quantity_skew
# Running experiments:  68%|██████▊   | 19/28 [2:45:15<1:28:09, 587.69s/it]
# ▶️  Running: mobilenetv2 on Quantity_skew
# Running experiments:  71%|███████▏  | 20/28 [2:58:00<1:25:26, 640.79s/it]
# ▶️  Running: tinycnn on IID_equal
# Running experiments:  75%|███████▌  | 21/28 [3:10:28<1:18:30, 672.88s/it]
# ▶️  Running: simplecnn on IID_equal
# Running experiments:  79%|███████▊  | 22/28 [3:19:52<1:04:02, 640.41s/it]
# ▶️  Running: resnet18 on IID_equal
# Running experiments:  82%|████████▏ | 23/28 [3:30:57<53:58, 647.79s/it]
# ▶️  Running: mobilenetv2 on IID_equal
# Running experiments:  86%|████████▌ | 24/28 [3:41:12<42:31, 637.82s/it]
# ▶️  Running: tinycnn on Dirichlet_label
# Running experiments:  89%|████████▉ | 25/28 [3:56:50<36:23, 727.88s/it]
# ▶️  Running: simplecnn on Dirichlet_label
# Running experiments:  93%|█████████▎| 26/28 [4:09:54<24:49, 744.88s/it]
# ▶️  Running: resnet18 on Dirichlet_label
# Running experiments:  96%|█████████▋| 27/28 [4:24:49<13:09, 789.90s/it]
# ▶️  Running: mobilenetv2 on Dirichlet_label
# Running experiments: 100%|██████████| 28/28 [4:38:34<00:00, 596.94s/it]

# %% [markdown]
# # Label_skew

# %%
# !python main.py tinycnn Label_skew
# Out:
# 2025-06-01 14:51:28.714439: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748789488.735681    9220 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748789488.742127    9220 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-01 14:51:28.763369: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-06-01 14:51:37,659	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'accelerator_type:A100': 1.0, 'node:__internal_head__': 1.0, 'CPU': 12.0, 'memory': 53541637326.0, 'node:172.28.0.12': 1.0, 'object_store_memory': 26770818662.0, 'GPU': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 12 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=10033) 2025-06-01 14:51:40.227351: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=10037) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=10037) E0000 00:00:1748789500.205165   10037 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=10037) E0000 00:00:1748789500.216024   10037 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# (ClientAppActor pid=10040) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=10040)             entirely in future versions of Flower.
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (pid=10040) 2025-06-01 14:51:40.386040: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=10040) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 11x across cluster]
# (pid=10040) E0000 00:00:1748789500.419266   10040 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 11x across cluster]
# (pid=10034) E0000 00:00:1748789500.374021   10034 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered [repeated 11x across cluster]
# INFO :      initial parameters (loss, other metrics): 0.0, {'accuracy': 0.31}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10040) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=10040)             entirely in future versions of Flower.
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=10038)             entirely in future versions of Flower.
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# INFO :      aggregate_fit: received 3 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 0.0, {'accuracy': 0.5566666666666666}, 36.44977179200009)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (2, 0.0, {'accuracy': 0.6266666666666667}, 75.18552122100004)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (3, 0.0, {'accuracy': 0.75}, 113.96669612900018)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (4, 0.0, {'accuracy': 0.7666666666666667}, 153.0115945970001)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (5, 0.0, {'accuracy': 0.7966666666666666}, 192.198535128)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (6, 0.0, {'accuracy': 0.81}, 231.42174690399997)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (7, 0.0, {'accuracy': 0.8166666666666667}, 270.32771020400014)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (8, 0.0, {'accuracy': 0.8433333333333334}, 309.3036463650001)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (9, 0.0, {'accuracy': 0.83}, 348.37315970300006)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (10, 0.0, {'accuracy': 0.7933333333333333}, 387.1167338050002)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038)
# (ClientAppActor pid=10038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10039)
# (ClientAppActor pid=10040)
# (ClientAppActor pid=10040)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 392.58s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.8981768560409545
# INFO :      		round 2: 0.888606493473053
# INFO :      		round 3: 0.6743883140881857
# INFO :      		round 4: 0.6145309122403463
# INFO :      		round 5: 0.5274332273006439
# INFO :      		round 6: 0.47865936875343323
# INFO :      		round 7: 0.47710609197616577
# INFO :      		round 8: 0.4630793062845866
# INFO :      		round 9: 0.43443044781684875
# INFO :      		round 10: 0.5148195397853851
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 0.0
# INFO :      		round 1: 0.0
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (metrics, centralized):
# INFO :      	{'accuracy': [(0, 0.31),
# INFO :      	              (1, 0.5566666666666666),
# INFO :      	              (2, 0.6266666666666667),
# INFO :      	              (3, 0.75),
# INFO :      	              (4, 0.7666666666666667),
# INFO :      	              (5, 0.7966666666666666),
# INFO :      	              (6, 0.81),
# INFO :      	              (7, 0.8166666666666667),
# INFO :      	              (8, 0.8433333333333334),
# INFO :      	              (9, 0.83),
# INFO :      	              (10, 0.7933333333333333)]}
# INFO :
# (ClientAppActor pid=10040) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=10040)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=10040)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=10040) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]

# %%
# !python main.py simplecnn Label_skew

# %%
# !python main.py resnet18 Label_skew

# %%
# !python main.py mobilenetv2 Label_skew

# %% [markdown]
# # Concept_shift

# %%
# !python main.py tinycnn Concept_shift

# %%
# !python main.py simplecnn Concept_shift

# %%
# !python main.py resnet18 Concept_shift

# %%
# !python main.py mobilenetv2 Concept_shift

# %% [markdown]
# # Feature_skew

# %%
# !python main.py tinycnn Feature_skew

# %%
# !python main.py simplecnn Feature_skew

# %%
# !python main.py resnet18 Feature_skew

# %%
# !python main.py mobilenetv2 Feature_skew

# %% [markdown]
# # Pathological

# %%
# !python main.py tinycnn Pathological
# Out:
# 2025-06-02 16:47:22.667002: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748882842.688243   10026 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748882842.694690   10026 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-02 16:47:22.716685: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  Removing empty folder: /content/drive/MyDrive/Colab Notebooks/Covid19-dataset/splits/Pathological/Client-1/Normal
#  Removing empty folder: /content/drive/MyDrive/Colab Notebooks/Covid19-dataset/splits/Pathological/Client-1/Viral Pneumonia
#  Removing empty folder: /content/drive/MyDrive/Colab Notebooks/Covid19-dataset/splits/Pathological/Client-2/Covid
#  Removing empty folder: /content/drive/MyDrive/Colab Notebooks/Covid19-dataset/splits/Pathological/Client-2/Viral Pneumonia
#  Removing empty folder: /content/drive/MyDrive/Colab Notebooks/Covid19-dataset/splits/Pathological/Client-3/Covid
#  Removing empty folder: /content/drive/MyDrive/Colab Notebooks/Covid19-dataset/splits/Pathological/Client-3/Normal
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-06-02 16:47:31,961	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'accelerator_type:A100': 1.0, 'node:__internal_head__': 1.0, 'CPU': 12.0, 'memory': 53585886414.0, 'node:172.28.0.12': 1.0, 'object_store_memory': 26792943206.0, 'GPU': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 12 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=10844) 2025-06-02 16:47:34.498830: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=10841) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=10841) E0000 00:00:1748882854.491410   10841 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=10841) E0000 00:00:1748882854.502692   10841 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# (ClientAppActor pid=10850) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=10850)             entirely in future versions of Flower.
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (pid=10843) 2025-06-02 16:47:34.649730: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=10843) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 11x across cluster]
# (pid=10843) E0000 00:00:1748882854.685538   10843 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 11x across cluster]
# (pid=10843) E0000 00:00:1748882854.696417   10843 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered [repeated 11x across cluster]
# INFO :      initial parameters (loss, other metrics): 0.0, {'accuracy': 0.0}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10850) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=10850)             entirely in future versions of Flower.
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=10849)             entirely in future versions of Flower.
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# INFO :      aggregate_fit: received 3 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 0.0, {'accuracy': 1.0}, 151.65319101600016)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (2, 0.0, {'accuracy': 1.0}, 197.2357916140004)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (3, 0.0, {'accuracy': 1.0}, 242.84949492500027)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (4, 0.0, {'accuracy': 1.0}, 287.162870485)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10848)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10848)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10848) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (5, 0.0, {'accuracy': 1.0}, 332.4577620070004)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (6, 0.0, {'accuracy': 1.0}, 378.2214063720003)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (7, 0.0, {'accuracy': 1.0}, 423.3037580910004)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (8, 0.0, {'accuracy': 1.0}, 467.626047321)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (9, 0.0, {'accuracy': 1.0}, 512.7235689890003)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (10, 0.0, {'accuracy': 1.0}, 557.5253859600002)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849)
# (ClientAppActor pid=10849) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=10849)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=10849)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=10849) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10848)
# (ClientAppActor pid=10850)
# (ClientAppActor pid=10850)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 563.77s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 1.6237778289183535e-08
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 0.0
# INFO :      		round 1: 0.0
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (metrics, centralized):
# INFO :      	{'accuracy': [(0, 0.0),
# INFO :      	              (1, 1.0),
# INFO :      	              (2, 1.0),
# INFO :      	              (3, 1.0),
# INFO :      	              (4, 1.0),
# INFO :      	              (5, 1.0),
# INFO :      	              (6, 1.0),
# INFO :      	              (7, 1.0),
# INFO :      	              (8, 1.0),
# INFO :      	              (9, 1.0),
# INFO :      	              (10, 1.0)]}
# INFO :
# (ClientAppActor pid=10850) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=10850)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=10850)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=10850) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]

# %%
# !python main.py simplecnn Pathological
# Out:
# 2025-06-02 16:59:31.686968: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748883571.708545   16215 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748883571.715216   16215 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-02 16:59:31.737107: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-06-02 16:59:40,648	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'accelerator_type:A100': 1.0, 'node:__internal_head__': 1.0, 'CPU': 12.0, 'memory': 53584261940.0, 'node:172.28.0.12': 1.0, 'object_store_memory': 26792130969.0, 'GPU': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 12 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=17029) 2025-06-02 16:59:43.183708: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=17028) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=17028) E0000 00:00:1748883583.213037   17028 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=17034) E0000 00:00:1748883583.213469   17034 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# (ClientAppActor pid=17037) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=17037)             entirely in future versions of Flower.
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (pid=17038) 2025-06-02 16:59:43.434658: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=17038) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 11x across cluster]
# (pid=17038) E0000 00:00:1748883583.472545   17038 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 11x across cluster]
# (pid=17038) E0000 00:00:1748883583.483516   17038 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered [repeated 11x across cluster]
# INFO :      initial parameters (loss, other metrics): 0.0, {'accuracy': 1.0}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17037) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=17037)             entirely in future versions of Flower.
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=17036)             entirely in future versions of Flower.
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 0.0, {'accuracy': 1.0}, 57.92424086100027)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (2, 0.0, {'accuracy': 1.0}, 121.14891832400008)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (3, 0.0, {'accuracy': 1.0}, 184.18213850500024)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (4, 0.0, {'accuracy': 1.0}, 245.4904585610002)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (5, 0.0, {'accuracy': 1.0}, 307.99045991)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17038)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17038)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (6, 0.0, {'accuracy': 1.0}, 370.3200298930001)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (7, 0.0, {'accuracy': 1.0}, 432.1039493200001)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (8, 0.0, {'accuracy': 1.0}, 494.5249386710002)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (9, 0.0, {'accuracy': 1.0}, 557.8973055060001)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (10, 0.0, {'accuracy': 1.0}, 620.8216850620001)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036)
# (ClientAppActor pid=17036) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=17036)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=17036)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=17036) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17037)
# (ClientAppActor pid=17038)
# (ClientAppActor pid=17038)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 628.47s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.31874066096207626
# INFO :      		round 2: 0.00020752080826033092
# INFO :      		round 3: 3.1683530218034257e-09
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 0.0
# INFO :      		round 1: 0.0
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (metrics, centralized):
# INFO :      	{'accuracy': [(0, 1.0),
# INFO :      	              (1, 1.0),
# INFO :      	              (2, 1.0),
# INFO :      	              (3, 1.0),
# INFO :      	              (4, 1.0),
# INFO :      	              (5, 1.0),
# INFO :      	              (6, 1.0),
# INFO :      	              (7, 1.0),
# INFO :      	              (8, 1.0),
# INFO :      	              (9, 1.0),
# INFO :      	              (10, 1.0)]}
# INFO :
# (ClientAppActor pid=17038) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=17038)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=17038)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=17038) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]

# %%
# !python main.py resnet18 Pathological
# Out:
# 2025-06-02 17:13:30.003172: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748884410.025438   21338 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748884410.032129   21338 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-02 17:13:30.053915: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-06-02 17:13:39,551	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'accelerator_type:A100': 1.0, 'node:__internal_head__': 1.0, 'CPU': 12.0, 'object_store_memory': 26792574566.0, 'node:172.28.0.12': 1.0, 'memory': 53585149134.0, 'GPU': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 12 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=22150) 2025-06-02 17:13:42.031711: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=22150) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=22150) E0000 00:00:1748884422.068123   22150 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=22150) E0000 00:00:1748884422.078932   22150 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (ClientAppActor pid=22159) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=22159)             entirely in future versions of Flower.
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (pid=22147) 2025-06-02 17:13:42.337849: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=22147) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 11x across cluster]
# (pid=22147) E0000 00:00:1748884422.375425   22147 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 11x across cluster]
# (pid=22147) E0000 00:00:1748884422.385612   22147 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered [repeated 11x across cluster]
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 0.0, {'accuracy': 0.0}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22159) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=22159)             entirely in future versions of Flower.
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=22158) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=22158)             entirely in future versions of Flower.
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# INFO :      aggregate_fit: received 3 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 0.0, {'accuracy': 1.0}, 69.50881897999989)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=22158)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=22158)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=22158) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22159)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22159)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22159) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (2, 0.0, {'accuracy': 1.0}, 143.9092149779999)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22158)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22158)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22158) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22158)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22158)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22158) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (3, 0.0, {'accuracy': 1.0}, 217.5118363309998)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (4, 0.0, {'accuracy': 1.0}, 289.84541617199966)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22159)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22159)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22159) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (5, 0.0, {'accuracy': 1.0}, 363.2644421780001)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22159)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22159)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22159) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (6, 0.0, {'accuracy': 1.0}, 436.21354191099954)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22159)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22159)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22159) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (7, 0.0, {'accuracy': 1.0}, 509.9883520689996)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22158)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22158)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22158) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22158)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22158)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22158) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (8, 0.0, {'accuracy': 1.0}, 582.96874411)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (9, 0.0, {'accuracy': 1.0}, 655.0740261409996)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (10, 0.0, {'accuracy': 1.0}, 727.2799344919999)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157)
# (ClientAppActor pid=22157) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=22157)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=22157)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=22157) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22158)
# (ClientAppActor pid=22159)
# (ClientAppActor pid=22159)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 735.45s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 1.7766522499268558e-06
# INFO :      		round 2: 1.9802206150210703e-09
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 0.0
# INFO :      		round 1: 0.0
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (metrics, centralized):
# INFO :      	{'accuracy': [(0, 0.0),
# INFO :      	              (1, 1.0),
# INFO :      	              (2, 1.0),
# INFO :      	              (3, 1.0),
# INFO :      	              (4, 1.0),
# INFO :      	              (5, 1.0),
# INFO :      	              (6, 1.0),
# INFO :      	              (7, 1.0),
# INFO :      	              (8, 1.0),
# INFO :      	              (9, 1.0),
# INFO :      	              (10, 1.0)]}
# INFO :
# (ClientAppActor pid=22159) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=22159)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=22159)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=22159) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]

# %%
# !python main.py mobilenetv2 Pathological
# Out:
# 2025-06-02 17:30:24.970775: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748885424.992287   27088 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748885424.998791   27088 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-02 17:30:25.020011: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=10, no round_timeout
# 2025-06-02 17:30:34,219	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'accelerator_type:A100': 1.0, 'node:__internal_head__': 1.0, 'CPU': 12.0, 'memory': 53586166580.0, 'node:172.28.0.12': 1.0, 'object_store_memory': 26793083289.0, 'GPU': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 12 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=27893) 2025-06-02 17:30:36.855048: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=27893) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=27893) E0000 00:00:1748885436.892994   27893 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=27893) E0000 00:00:1748885436.904053   27893 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# (ClientAppActor pid=27901) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=27901)             entirely in future versions of Flower.
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (pid=27895) 2025-06-02 17:30:37.191889: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=27895) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 11x across cluster]
# (pid=27895) E0000 00:00:1748885437.229816   27895 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 11x across cluster]
# (pid=27895) E0000 00:00:1748885437.241126   27895 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered [repeated 11x across cluster]
# INFO :      initial parameters (loss, other metrics): 0.0, {'accuracy': 0.0}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27901) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=27901)             entirely in future versions of Flower.
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=27900) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=27900)             entirely in future versions of Flower.
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# INFO :      aggregate_fit: received 3 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 0.0, {'accuracy': 1.0}, 64.66355860000021)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=27900)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=27900)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=27900) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27901)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27901)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27901) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (2, 0.0, {'accuracy': 1.0}, 132.13976991399977)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27899)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27899)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27899) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27901)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27901)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27901) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (3, 0.0, {'accuracy': 1.0}, 198.42582602600032)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27899)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27899)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27899) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27899)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27899)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27899) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (4, 0.0, {'accuracy': 1.0}, 263.9017614840004)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27899)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27899)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27899) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27900)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27900)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27900) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (5, 0.0, {'accuracy': 1.0}, 330.162065857)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27901)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27901)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27901) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27901)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27901)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27901) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (6, 0.0, {'accuracy': 1.0}, 397.24870531000033)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27901)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27901)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27901) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27899)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27899)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27899) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (7, 0.0, {'accuracy': 1.0}, 463.5565667179999)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27899)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27899)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27899) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27900)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27900)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27900) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (8, 0.0, {'accuracy': 1.0}, 529.9255290370002)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27899)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27899)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27899) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27899)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27899)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27899) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (9, 0.0, {'accuracy': 1.0}, 595.9767501189999)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27900)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27900)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27900) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27901)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27901)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27901) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      fit progress: (10, 0.0, {'accuracy': 1.0}, 662.1483821110005)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900)
# (ClientAppActor pid=27900) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=27900)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=27900)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=27900) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27901)
# (ClientAppActor pid=27899)
# (ClientAppActor pid=27899)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 669.74s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.01900440635178176
# INFO :      		round 2: 9.298280929215252e-06
# INFO :      		round 3: 1.1920928180798998e-07
# INFO :      		round 4: 2.3841856361597995e-07
# INFO :      		round 5: 2.4119086512135776e-07
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 0.0
# INFO :      		round 1: 0.0
# INFO :      		round 2: 0.0
# INFO :      		round 3: 0.0
# INFO :      		round 4: 0.0
# INFO :      		round 5: 0.0
# INFO :      		round 6: 0.0
# INFO :      		round 7: 0.0
# INFO :      		round 8: 0.0
# INFO :      		round 9: 0.0
# INFO :      		round 10: 0.0
# INFO :      	History (metrics, centralized):
# INFO :      	{'accuracy': [(0, 0.0),
# INFO :      	              (1, 1.0),
# INFO :      	              (2, 1.0),
# INFO :      	              (3, 1.0),
# INFO :      	              (4, 1.0),
# INFO :      	              (5, 1.0),
# INFO :      	              (6, 1.0),
# INFO :      	              (7, 1.0),
# INFO :      	              (8, 1.0),
# INFO :      	              (9, 1.0),
# INFO :      	              (10, 1.0)]}
# INFO :
# (ClientAppActor pid=27899) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=27899)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=27899)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=27899) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]

# %% [markdown]
# # Dirichlet_label

# %%
# !python main.py tinycnn Dirichlet_label

# %%
# !python main.py tinycnn Dirichlet_label

# %%
# !python main.py tinycnn Dirichlet_label

# %%
# !python main.py tinycnn Dirichlet_label

# %% [markdown]
# # Quantity_skew

# %%
# !python main.py tinycnn Quantity_skew

# %%
# !python main.py tinycnn Quantity_skew

# %%
# !python main.py tinycnn Quantity_skew

# %%
# !python main.py tinycnn Quantity_skew

# %% [markdown]
# # IID_equal

# %%
# !python main.py tinycnn IID_equal

# %%
# !python main.py tinycnn IID_equal

# %%
# !python main.py tinycnn IID_equal

# %%
# !python main.py tinycnn IID_equal
